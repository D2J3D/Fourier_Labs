# %%
import numpy as np
import cmath
from numpy import cos, sin
import random
import math
import matplotlib.pyplot as plt

# %%
a = 4
T = 1
W_1 = lambda w: a/(a + w**2) + 1j * (-a * w)/(a + w**2)

# %%
# Построим АЧХ
w_line = np.linspace(0, 100, 10000)
W_Amp = [cmath.polar(W_1(w))[0] for w in w_line] #[np.sqrt(np.real(W_1(w))**2 + np.imag(W_1(w))**2) for w in w_line]
W_Phase = [cmath.polar(W_1(w))[1] for w in w_line]
# print(W_Phase)

# %%
fig, ax = plt.subplots(2, 1)
ax[0].plot(w_line, W_Amp)
# print(W_Phase)
ax[1].plot(w_line, W_Phase)
ax[0].grid(True)
ax[1].grid(True)
plt.show()
