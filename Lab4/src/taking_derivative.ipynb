# %%
import numpy as np
from numpy import sin, cos, exp, pi
import matplotlib.pyplot as plt
import random

# %%
time = np.linspace(-100, 100, 1000)
a = .1
y = lambda t: sin(t) + a * (random.uniform(0, 1) - 0.5)

# %%
fig, ax = plt.subplots()
ax.plot(time, [y(i) for i in time])
ax.grid(True)
plt.show()
None

# %%
def find_num_derivative_array(yt, dt):
    return [(yt[k + 1] - yt[k]) / dt for k in range(len(yt) - 1)]

# %%
# test dericative calculation on a simple function
fig, ax = plt.subplots(2)
test_time = np.arange(-6.28, 6.28, dt)
test_yt = [cos(ts) for ts in test_time]
test_yt_d = find_num_derivative_array([sin(ts) for ts in test_time], dt)
ax[0].plot(test_time, test_yt)
ax[1].plot(test_time[:-1], test_yt_d)
None
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 # test dericative calculation on a simple function
#       2 fig, ax = plt.subplots(2)
# ----> 3 test_time = np.arange(-6.28, 6.28, dt)
#       4 test_yt = [cos(ts) for ts in test_time]
#       5 test_yt_d = find_num_derivative_array([sin(ts) for ts in test_time], dt)
#
# NameError: name 'dt' is not defined
